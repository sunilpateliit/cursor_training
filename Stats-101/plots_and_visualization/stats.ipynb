# %%
import pandas as pd 
from sklearn.datasets import load_iris

# %%
# Load the Iris dataset
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['species'] = iris.target_names[iris.target]

# Display first few rows and basic info
print("Dataset shape:", df.shape)
print("\nFirst 5 rows:")
print(df.head())
print("\nDataset info:")
print(df.info())
print("\nBasic statistics:")
print(df.describe())
# Out:
# Dataset shape: (150, 5)
#
# First 5 rows:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
# ...

# %%
df_clean = df.dropna().drop_duplicates()

# %%
freq_table = pd.cut(df_clean['sepal length (cm)'], bins=3, labels=False)
freq_table.value_counts()
# # Create histograms for all numerical features
# Out:
# sepal length (cm)
# 1    70
# 0    59
# 2    20
# Name: count, dtype: int64

# %%
# # Create histograms for all numerical features
# fig, axes = plt.subplots(2, 2, figsize=(12, 10))
# fig.suptitle('Histograms of Iris Dataset Features', fontsize=16, fontweight='bold')

# # Numerical features
# features = iris.feature_names

# for i, feature in enumerate(features):
#     ax = axes[i//2, i%2]
#     sns.histplot(data=df, x=feature, ax=ax, bins=20, alpha=0.7, edgecolor='black')
#     ax.set_title(f'Histogram of {feature}')
#     ax.set_xlabel(feature)
#     ax.set_ylabel('Frequency')

# plt.tight_layout()
# plt.show()

# # Individual histogram with species separation
# plt.figure(figsize=(10, 6))
# sns.histplot(data=df, x='sepal length (cm)', hue='species', multiple='stack', bins=15, alpha=0.7)
# plt.title('Histogram of Sepal Length by Species')
# plt.xlabel('Sepal Length (cm)')
# plt.ylabel('Frequency')
# plt.legend(title='Species', bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
# plt.show()

# %%
# # Kernel Density Estimation (KDE) plots
# fig, axes = plt.subplots(2, 2, figsize=(12, 10))
# fig.suptitle('Kernel Density Estimation Plots', fontsize=16, fontweight='bold')

# for i, feature in enumerate(features):
#     ax = axes[i//2, i%2]
#     sns.kdeplot(data=df, x=feature, ax=ax, fill=True, alpha=0.6)
#     ax.set_title(f'KDE of {feature}')
#     ax.set_xlabel(feature)
#     ax.set_ylabel('Density')

# plt.tight_layout()
# plt.show()

# # KDE plots with species comparison
# plt.figure(figsize=(15, 10))

# for i, feature in enumerate(features):
#     plt.subplot(2, 2, i+1)
#     sns.kdeplot(data=df, x=feature, hue='species', fill=True, alpha=0.4)
#     plt.title(f'KDE of {feature} by Species')
#     plt.xlabel(feature)
#     plt.ylabel('Density')

# plt.tight_layout()
# plt.show()

# # Combined histogram and KDE plot
# plt.figure(figsize=(10, 6))
# sns.histplot(data=df, x='petal length (cm)', kde=True, bins=20, alpha=0.7)
# plt.title('Histogram with KDE Overlay - Petal Length')
# plt.xlabel('Petal Length (cm)')
# plt.ylabel('Density/Frequency')
# plt.show()

# %%
# # Estimation plots - Box plots, Violin plots, and Point plots

# # Box plots for each feature by species
# fig, axes = plt.subplots(2, 2, figsize=(12, 10))
# fig.suptitle('Box Plots: Feature Distributions by Species', fontsize=16, fontweight='bold')

# for i, feature in enumerate(features):
#     ax = axes[i//2, i%2]
#     sns.boxplot(data=df, x='species', y=feature, ax=ax, palette='Set3')
#     ax.set_title(f'Box Plot of {feature}')
#     ax.set_xlabel('Species')
#     ax.set_ylabel(feature)

# plt.tight_layout()
# plt.show()

# # Violin plots (combines box plot with KDE)
# plt.figure(figsize=(15, 10))
# for i, feature in enumerate(features):
#     plt.subplot(2, 2, i+1)
#     sns.violinplot(data=df, x='species', y=feature, palette='Set2', inner='quartile')
#     plt.title(f'Violin Plot of {feature} by Species')
#     plt.xlabel('Species')
#     plt.ylabel(feature)

# plt.tight_layout()
# plt.show()

# # Point plots with confidence intervals
# plt.figure(figsize=(15, 10))
# for i, feature in enumerate(features):
#     plt.subplot(2, 2, i+1)
#     sns.pointplot(data=df, x='species', y=feature, palette='dark', capsize=0.1, errwidth=2)
#     plt.title(f'Point Plot with CI: {feature} by Species')
#     plt.xlabel('Species')
#     plt.ylabel(feature)

# plt.tight_layout()
# plt.show()

# # Swarm plot for detailed distribution view
# plt.figure(figsize=(15, 10))
# for i, feature in enumerate(features):
#     plt.subplot(2, 2, i+1)
#     sns.swarmplot(data=df, x='species', y=feature, palette='husl', alpha=0.7)
#     plt.title(f'Swarm Plot of {feature} by Species')
#     plt.xlabel('Species')
#     plt.ylabel(feature)

# plt.tight_layout()
# plt.show()

# %%
# # Additional statistical visualizations

# # Correlation heatmap
# plt.figure(figsize=(8, 6))
# correlation_matrix = df.drop('species', axis=1).corr()
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0,
#             square=True, linewidths=0.5)
# plt.title('Correlation Heatmap of Iris Features')
# plt.show()

# # Pair plot - shows relationships between all variables
# plt.figure(figsize=(10, 8))
# pair_plot = sns.pairplot(df, hue='species', diag_kind='kde', palette='husl',
#                         plot_kws={'alpha': 0.6}, diag_kws={'fill': True})
# pair_plot.fig.suptitle('Pair Plot of Iris Dataset', y=1.02, fontsize=16, fontweight='bold')
# plt.show()

# # Distribution comparison with different plot types
# fig, axes = plt.subplots(2, 3, figsize=(15, 10))
# fig.suptitle('Multiple Distribution Plots for Sepal Length', fontsize=16, fontweight='bold')

# # Histogram
# sns.histplot(data=df, x='sepal length (cm)', ax=axes[0,0], bins=15)
# axes[0,0].set_title('Histogram')

# # KDE
# sns.kdeplot(data=df, x='sepal length (cm)', ax=axes[0,1], fill=True)
# axes[0,1].set_title('KDE Plot')

# # Box plot
# sns.boxplot(data=df, y='sepal length (cm)', ax=axes[0,2])
# axes[0,2].set_title('Box Plot')

# # Violin plot
# sns.violinplot(data=df, y='sepal length (cm)', ax=axes[1,0], inner='quartile')
# axes[1,0].set_title('Violin Plot')

# # Strip plot
# sns.stripplot(data=df, y='sepal length (cm)', ax=axes[1,1], alpha=0.7, jitter=True)
# axes[1,1].set_title('Strip Plot')

# # ECDF plot
# sns.ecdfplot(data=df, x='sepal length (cm)', ax=axes[1,2])
# axes[1,2].set_title('ECDF Plot')

# plt.tight_layout()
# plt.show()
